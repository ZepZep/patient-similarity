# %% [markdown]
# # Notebook for visualizing vectorization ablation results

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
import json
import random
from pprint import pprint
import re

from itertools import product, combinations
import importlib

from contextlib import redirect_stderr
import io
import sys
import os
import glob
from pathlib import Path

from sklearn.metrics.pairwise import cosine_similarity
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from tqdm.auto import tqdm

AICOPE_PY_LIB = os.environ.get("AICOPE_PY_LIB")
if AICOPE_PY_LIB and AICOPE_PY_LIB not in sys.path: sys.path.append(AICOPE_PY_LIB)
import importlib
import aicnlp
importlib.reload(aicnlp)

# %config Completer.use_jedi = False
PACSIM_DATA = os.environ.get("AICOPE_SCRATCH") + "/pacsim"

# %%
from aicnlp import emb_mgr
importlib.reload(emb_mgr)

mgr = emb_mgr.EmbMgr("/workspace/scratch/pacsim/mgrdata")

# %%
from aicnlp.validation.agreement import extract_annotations

with open("/home/ubuntu/petr/similarity/validace/evaluation-response-20220907.json", encoding='utf-8') as f:
    valdata = json.load(f)

# %% [markdown]
# ### Read data from all ablation experiments and calculate correlations

# %%
def read_abl_matsim(path):
    matsim = np.load(path)
    fname = Path(path).with_suffix("").name
    matmethod, rest, _ = fname.split("-")
    abldict = {"R": matmethod}
    for param in rest.split("_"):
        abldict[param[0]] = param[1:]
    return abldict, matsim 

def matsim_row(matsim, id_pac, mgr):
    pid = mgr.tr["id_pac", "pid"][str(id_pac)]
    try:
        pac_row = list(matsim["patients"]).index(pid)
    except ValueError:
        return None
    return pac_row

def extract_abl_predictions(annotations, matrix_files, mgr):
    predictions = []
    unknown = set()
    cat = "all"
    for abldict, matsim in tqdm(map(read_abl_matsim, matrix_files), total=len(matrix_files), desc="Predictions"):
        for pivot, proxy in annotations.groupby(["pivot", "proxy"]).groups.keys():
            value = -100

            pivot_index = matsim_row(matsim, pivot, mgr)
            if pivot_index is None:
                value = None
                unknown.add((cat+"_pivot", pivot))

            proxy_index = matsim_row(matsim, proxy, mgr)
            if proxy_index is None:
                value = None
                unknown.add((cat+"_proxy", proxy))

            if value is not None:
                value = matsim["sim"][pivot_index, proxy_index]

            predictions.append({
                "pivot": pivot,
                "proxy": proxy,
                # "cat": cat,
                **abldict,
                "value": value,
                
            })

    return pd.DataFrame.from_records(predictions), unknown


corr_fcn = lambda x, y: stats.kendalltau(x, y, nan_policy='omit', alternative="greater")


def get_correlations_all(mean_annotations, predictions):
    correlations = []
    groupcols = list(predictions.columns)[:-2]
    ann_dict = {pivot: dict(list(rest.groupby("cat"))) for pivot, rest in mean_annotations.groupby("pivot")}
    for modellist, pred in tqdm(predictions.groupby(groupcols, dropna=False)[["proxy", "value"]], desc="Correlations"):
        modeldict = dict(zip(groupcols, modellist))
        # print(modeldict)
        pivot = modeldict["pivot"]
        for cat, ann in ann_dict[pivot].items():
            # print(f"{pivot}, {cat}, {len(ann)}")
            pred = pred.sort_values("proxy")
            ann = ann.sort_values("proxy")
            
            c, p = corr_fcn(pred["value"], ann["value"])
            correlations.append({
                **modeldict,
                "pivot": pivot,
                "cat": cat,
                "value": c,
                "pval": p,
            })
    return pd.DataFrame.from_records(correlations)


def move_to_end(df, to_move):
    for moving in to_move:
        col = df.pop(moving)
        df[moving] = col

def get_ablation_data(valdata, matrix_files, mgr):
    annotations, mean_annotations = extract_annotations(valdata)
    predictions, unknown = extract_abl_predictions(annotations, matrix_files, mgr)
    move_to_end(predictions, ["pivot", "proxy", "value"])
    
    correlations = get_correlations_all(mean_annotations, predictions)
    move_to_end(correlations, ["pivot", "value", "pval"])

    return annotations, mean_annotations, predictions, correlations

matrix_files = sorted(glob.glob(f"{PACSIM_DATA}/3/*AV*"))
annotations, mean_annotations, predictions, correlations = get_ablation_data(valdata, matrix_files, mgr)
correlations
# Out:
# Predictions:   0%|          | 0/444 [00:00<?, ?it/s]
# Correlations:   0%|          | 0/4440 [00:00<?, ?it/s]
#           R     A   d    m    w    e    a    i    f cat   pivot     value  \
# 0      Reds  Vd2v  50    3    3   30    1  NaN  NaN  01  102913  0.400000
# 1      Reds  Vd2v  50    3    3   30    1  NaN  NaN  02  102913 -0.400000
# 2      Reds  Vd2v  50    3    3   30    1  NaN  NaN  03  102913  0.200000
# 3      Reds  Vd2v  50    3    3   30    1  NaN  NaN  04  102913  0.200000
# 4      Reds  Vd2v  50    3    3   30    1  NaN  NaN  05  102913 -0.200000
# ...     ...   ...  ..  ...  ...  ...  ...  ...  ...  ..     ...       ...
# 44395  Rrv2  Vrbc  50  NaN  NaN  NaN  NaN   30    1  06   80561 -0.774597
# 44396  Rrv2  Vrbc  50  NaN  NaN  NaN  NaN   30    1  07   80561  0.600000
# 44397  Rrv2  Vrbc  50  NaN  NaN  NaN  NaN   30    1  08   80561  0.737865
# 44398  Rrv2  Vrbc  50  NaN  NaN  NaN  NaN   30    1  09   80561  0.400000
# 44399  Rrv2  Vrbc  50  NaN  NaN  NaN  NaN   30    1  10   80561  0.400000
#
#            pval
# 0      0.241667
# 1      0.883333
# 2      0.408333
# 3      0.408333
# 4      0.758333
# ...         ...
# 44395  0.958368
# 44396  0.116667
# 44397  0.038487
# 44398  0.241667
# 44399  0.241667
#
# [44400 rows x 13 columns]

# %%
def latexify(text):
    return re.sub(
        r"\\background-color#([0-9a-f]*) \\color#([0-9a-f]*) (\S*)",
        r"\\cellcolor[HTML]{\1}{\\color[HTML]{\2} \3} ",
        text
    )

def print_abl_table(table):
    print(latexify(table.to_latex(sparse_index=False)))

# %% [markdown]
# ### lsa results

# %%
results = correlations.query("A == 'Vlsa'").query("cat in ['07', '08', '09']").pivot_table(index="R", columns=["i", "m"], values="value")
ps = results.style.format("{:.2f}").background_gradient(cmap="RdYlGn", vmin=results.min().min(), vmax=results.max().max())
display(ps)
print_abl_table(ps)
# Out:
# <style type="text/css">
# #T_a12a7_row0_col0, #T_a12a7_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a12a7_row0_col2, #T_a12a7_row0_col3, #T_a12a7_row0_col4, #T_a12a7_row0_col6, #T_a12a7_row0_col7 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_a12a7_row0_col5, #T_a12a7_row0_col8 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_a12a7_row1_col0, #T_a12a7_row1_col1, #T_a12a7_row1_col2, #T_a12a7_row1_col3, #T_a12a7_row1_col4, #T_a12a7_row1_col5, #T_a12a7_row1_col6, #T_a12a7_row1_col7, #T_a12a7_row1_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a12a7_row2_col0, #T_a12a7_row2_col1, #T_a12a7_row2_col2, #T_a12a7_row2_col3, #T_a12a7_row2_col4, #T_a12a7_row2_col5, #T_a12a7_row2_col6, #T_a12a7_row2_col7, #T_a12a7_row2_col8 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a12a7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >i</th>
#       <th id="T_a12a7_level0_col0" class="col_heading level0 col0" colspan="3">10</th>
#       <th id="T_a12a7_level0_col3" class="col_heading level0 col3" colspan="3">20</th>
#       <th id="T_a12a7_level0_col6" class="col_heading level0 col6" colspan="3">30</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >m</th>
#       <th id="T_a12a7_level1_col0" class="col_heading level1 col0" >1</th>
#       <th id="T_a12a7_level1_col1" class="col_heading level1 col1" >2</th>
#       <th id="T_a12a7_level1_col2" class="col_heading level1 col2" >3</th>
#       <th id="T_a12a7_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_a12a7_level1_col4" class="col_heading level1 col4" >2</th>
#       <th id="T_a12a7_level1_col5" class="col_heading level1 col5" >3</th>
#       <th id="T_a12a7_level1_col6" class="col_heading level1 col6" >1</th>
#       <th id="T_a12a7_level1_col7" class="col_heading level1 col7" >2</th>
#       <th id="T_a12a7_level1_col8" class="col_heading level1 col8" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >R</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12a7_level0_row0" class="row_heading level0 row0" >Reds</th>
#       <td id="T_a12a7_row0_col0" class="data row0 col0" >0.36</td>
#       <td id="T_a12a7_row0_col1" class="data row0 col1" >0.36</td>
#       <td id="T_a12a7_row0_col2" class="data row0 col2" >0.40</td>
#       <td id="T_a12a7_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_a12a7_row0_col4" class="data row0 col4" >0.40</td>
#       <td id="T_a12a7_row0_col5" class="data row0 col5" >0.38</td>
#       <td id="T_a12a7_row0_col6" class="data row0 col6" >0.40</td>
#       <td id="T_a12a7_row0_col7" class="data row0 col7" >0.40</td>
#       <td id="T_a12a7_row0_col8" class="data row0 col8" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_a12a7_level0_row1" class="row_heading level0 row1" >Rmms</th>
#       <td id="T_a12a7_row1_col0" class="data row1 col0" >0.47</td>
#       <td id="T_a12a7_row1_col1" class="data row1 col1" >0.47</td>
#       <td id="T_a12a7_row1_col2" class="data row1 col2" >0.47</td>
#       <td id="T_a12a7_row1_col3" class="data row1 col3" >0.47</td>
#       <td id="T_a12a7_row1_col4" class="data row1 col4" >0.47</td>
#       <td id="T_a12a7_row1_col5" class="data row1 col5" >0.47</td>
#       <td id="T_a12a7_row1_col6" class="data row1 col6" >0.47</td>
#       <td id="T_a12a7_row1_col7" class="data row1 col7" >0.47</td>
#       <td id="T_a12a7_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_a12a7_level0_row2" class="row_heading level0 row2" >Rrv2</th>
#       <td id="T_a12a7_row2_col0" class="data row2 col0" >0.46</td>
#       <td id="T_a12a7_row2_col1" class="data row2 col1" >0.46</td>
#       <td id="T_a12a7_row2_col2" class="data row2 col2" >0.46</td>
#       <td id="T_a12a7_row2_col3" class="data row2 col3" >0.46</td>
#       <td id="T_a12a7_row2_col4" class="data row2 col4" >0.46</td>
#       <td id="T_a12a7_row2_col5" class="data row2 col5" >0.46</td>
#       <td id="T_a12a7_row2_col6" class="data row2 col6" >0.46</td>
#       <td id="T_a12a7_row2_col7" class="data row2 col7" >0.46</td>
#       <td id="T_a12a7_row2_col8" class="data row2 col8" >0.46</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrrrrrrr}
# i & \multicolumn{3}{r}{10} & \multicolumn{3}{r}{20} & \multicolumn{3}{r}{30} \\
# m & 1 & 2 & 3 & 1 & 2 & 3 & 1 & 2 & 3 \\
# R &  &  &  &  &  &  &  &  &  \\
# Reds & \cellcolor[HTML]{a50026}{\color[HTML]{f1f1f1} 0.36}  & \cellcolor[HTML]{a50026}{\color[HTML]{f1f1f1} 0.36}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.40}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.40}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.40}  & \cellcolor[HTML]{ed5f3c}{\color[HTML]{f1f1f1} 0.38}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.40}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.40}  & \cellcolor[HTML]{ed5f3c}{\color[HTML]{f1f1f1} 0.38}  \\
# Rmms & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.47}  \\
# Rrv2 & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.46}  \\
# \end{tabular}

# %% [markdown]
# ### rbc results

# %%
results = correlations.query("A == 'Vrbc'").query("cat in ['07', '08', '09']").pivot_table(index="R", columns=["f", "i"], values="value")
ps = results.style.format("{:.2f}").background_gradient(cmap="RdYlGn", vmin=results.min().min(), vmax=results.max().max())
display(ps)
print_abl_table(ps)
# Out:
# <style type="text/css">
# #T_d6e8d_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d6e8d_row0_col1, #T_d6e8d_row0_col2, #T_d6e8d_row0_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_d6e8d_row1_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_d6e8d_row1_col1, #T_d6e8d_row1_col2, #T_d6e8d_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d6e8d_row2_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_d6e8d_row2_col1, #T_d6e8d_row2_col2, #T_d6e8d_row2_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# </style>
# <table id="T_d6e8d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >f</th>
#       <th id="T_d6e8d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d6e8d_level0_col1" class="col_heading level0 col1" colspan="3">1</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >i</th>
#       <th id="T_d6e8d_level1_col0" class="col_heading level1 col0" >10</th>
#       <th id="T_d6e8d_level1_col1" class="col_heading level1 col1" >10</th>
#       <th id="T_d6e8d_level1_col2" class="col_heading level1 col2" >20</th>
#       <th id="T_d6e8d_level1_col3" class="col_heading level1 col3" >30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >R</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6e8d_level0_row0" class="row_heading level0 row0" >Reds</th>
#       <td id="T_d6e8d_row0_col0" class="data row0 col0" >0.32</td>
#       <td id="T_d6e8d_row0_col1" class="data row0 col1" >0.36</td>
#       <td id="T_d6e8d_row0_col2" class="data row0 col2" >0.36</td>
#       <td id="T_d6e8d_row0_col3" class="data row0 col3" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_d6e8d_level0_row1" class="row_heading level0 row1" >Rmms</th>
#       <td id="T_d6e8d_row1_col0" class="data row1 col0" >0.34</td>
#       <td id="T_d6e8d_row1_col1" class="data row1 col1" >0.50</td>
#       <td id="T_d6e8d_row1_col2" class="data row1 col2" >0.50</td>
#       <td id="T_d6e8d_row1_col3" class="data row1 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_d6e8d_level0_row2" class="row_heading level0 row2" >Rrv2</th>
#       <td id="T_d6e8d_row2_col0" class="data row2 col0" >0.33</td>
#       <td id="T_d6e8d_row2_col1" class="data row2 col1" >0.41</td>
#       <td id="T_d6e8d_row2_col2" class="data row2 col2" >0.41</td>
#       <td id="T_d6e8d_row2_col3" class="data row2 col3" >0.41</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrrr}
# f & 0 & \multicolumn{3}{r}{1} \\
# i & 10 & 10 & 20 & 30 \\
# R &  &  &  &  \\
# Reds & \cellcolor[HTML]{a50026}{\color[HTML]{f1f1f1} 0.32}  & \cellcolor[HTML]{f57547}{\color[HTML]{f1f1f1} 0.36}  & \cellcolor[HTML]{f57547}{\color[HTML]{f1f1f1} 0.36}  & \cellcolor[HTML]{f57547}{\color[HTML]{f1f1f1} 0.36}  \\
# Rmms & \cellcolor[HTML]{d83128}{\color[HTML]{f1f1f1} 0.34}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.50}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.50}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.50}  \\
# Rrv2 & \cellcolor[HTML]{c62027}{\color[HTML]{f1f1f1} 0.33}  & \cellcolor[HTML]{fffab6}{\color[HTML]{000000} 0.41}  & \cellcolor[HTML]{fffab6}{\color[HTML]{000000} 0.41}  & \cellcolor[HTML]{fffab6}{\color[HTML]{000000} 0.41}  \\
# \end{tabular}

# %% [markdown]
# ### d2v results

# %%
results = correlations.query("A == 'Vd2v'").query("cat in ['07', '08', '09']").pivot_table(index=["R", "w"], columns=["e", "m"], values="value", aggfunc="mean")
ps = results.style.format("{:.2f}").background_gradient(cmap="RdYlGn", vmin=results.min().min(), vmax=results.max().max())
display(ps)
print_abl_table(ps)
# Out:
# <style type="text/css">
# #T_f7bb0_row0_col0, #T_f7bb0_row0_col6, #T_f7bb0_row4_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_f7bb0_row0_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_f7bb0_row0_col2, #T_f7bb0_row4_col0 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_f7bb0_row0_col3 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_f7bb0_row0_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_f7bb0_row0_col5 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_f7bb0_row0_col7, #T_f7bb0_row5_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_f7bb0_row0_col8 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_f7bb0_row1_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_f7bb0_row1_col1 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_f7bb0_row1_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_f7bb0_row1_col3 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_f7bb0_row1_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_f7bb0_row1_col5 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_f7bb0_row1_col6 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_f7bb0_row1_col7 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_f7bb0_row1_col8 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_f7bb0_row2_col0, #T_f7bb0_row2_col8 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col1, #T_f7bb0_row2_col4 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col5 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col6 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_f7bb0_row2_col7 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_f7bb0_row3_col0 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_f7bb0_row3_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_f7bb0_row3_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_f7bb0_row3_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_f7bb0_row3_col4, #T_f7bb0_row4_col8 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_f7bb0_row3_col5 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_f7bb0_row3_col6 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_f7bb0_row3_col7 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_f7bb0_row3_col8 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_f7bb0_row4_col1 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_f7bb0_row4_col2 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_f7bb0_row4_col4 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_f7bb0_row4_col5 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_f7bb0_row4_col6 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_f7bb0_row4_col7 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_f7bb0_row5_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_f7bb0_row5_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_f7bb0_row5_col2, #T_f7bb0_row5_col6, #T_f7bb0_row5_col8 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_f7bb0_row5_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_f7bb0_row5_col4 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_f7bb0_row5_col7 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_f7bb0_row6_col0, #T_f7bb0_row7_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col1 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col3 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col4 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col5 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col6, #T_f7bb0_row8_col4 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col7 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_f7bb0_row6_col8 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col2, #T_f7bb0_row8_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col3 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col5, #T_f7bb0_row7_col7 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col6, #T_f7bb0_row8_col2 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_f7bb0_row7_col8 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col0 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col5 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col6 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col7 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_f7bb0_row8_col8 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7bb0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >e</th>
#       <th id="T_f7bb0_level0_col0" class="col_heading level0 col0" colspan="3">30</th>
#       <th id="T_f7bb0_level0_col3" class="col_heading level0 col3" colspan="3">40</th>
#       <th id="T_f7bb0_level0_col6" class="col_heading level0 col6" colspan="3">50</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >m</th>
#       <th id="T_f7bb0_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_f7bb0_level1_col1" class="col_heading level1 col1" >5</th>
#       <th id="T_f7bb0_level1_col2" class="col_heading level1 col2" >7</th>
#       <th id="T_f7bb0_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_f7bb0_level1_col4" class="col_heading level1 col4" >5</th>
#       <th id="T_f7bb0_level1_col5" class="col_heading level1 col5" >7</th>
#       <th id="T_f7bb0_level1_col6" class="col_heading level1 col6" >3</th>
#       <th id="T_f7bb0_level1_col7" class="col_heading level1 col7" >5</th>
#       <th id="T_f7bb0_level1_col8" class="col_heading level1 col8" >7</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >R</th>
#       <th class="index_name level1" >w</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7bb0_level0_row0" class="row_heading level0 row0" rowspan="3">Reds</th>
#       <th id="T_f7bb0_level1_row0" class="row_heading level1 row0" >3</th>
#       <td id="T_f7bb0_row0_col0" class="data row0 col0" >0.28</td>
#       <td id="T_f7bb0_row0_col1" class="data row0 col1" >0.21</td>
#       <td id="T_f7bb0_row0_col2" class="data row0 col2" >0.28</td>
#       <td id="T_f7bb0_row0_col3" class="data row0 col3" >0.30</td>
#       <td id="T_f7bb0_row0_col4" class="data row0 col4" >0.29</td>
#       <td id="T_f7bb0_row0_col5" class="data row0 col5" >0.27</td>
#       <td id="T_f7bb0_row0_col6" class="data row0 col6" >0.28</td>
#       <td id="T_f7bb0_row0_col7" class="data row0 col7" >0.23</td>
#       <td id="T_f7bb0_row0_col8" class="data row0 col8" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_f7bb0_level1_row1" class="row_heading level1 row1" >5</th>
#       <td id="T_f7bb0_row1_col0" class="data row1 col0" >0.19</td>
#       <td id="T_f7bb0_row1_col1" class="data row1 col1" >0.24</td>
#       <td id="T_f7bb0_row1_col2" class="data row1 col2" >0.20</td>
#       <td id="T_f7bb0_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_f7bb0_row1_col4" class="data row1 col4" >0.23</td>
#       <td id="T_f7bb0_row1_col5" class="data row1 col5" >0.22</td>
#       <td id="T_f7bb0_row1_col6" class="data row1 co
# \begin{tabular}{llrrrrrrrrr}
#  & e & \multicolumn{3}{r}{30} & \multicolumn{3}{r}{40} & \multicolumn{3}{r}{50} \\
#  & m & 3 & 5 & 7 & 3 & 5 & 7 & 3 & 5 & 7 \\
# R & w &  &  &  &  &  &  &  &  &  \\
# Reds & 3 & \cellcolor[HTML]{feda86}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{f67c4a}{\color[HTML]{f1f1f1} 0.21}  & \cellcolor[HTML]{fed683}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{feea9b}{\color[HTML]{000000} 0.30}  & \cellcolor[HTML]{fee491}{\color[HTML]{000000} 0.29}  & \cellcolor[HTML]{fec877}{\color[HTML]{000000} 0.27}  & \cellcolor[HTML]{feda86}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{fa9656}{\color[HTML]{000000} 0.23}  & \cellcolor[HTML]{fecc7b}{\color[HTML]{000000} 0.27}  \\
# Reds & 5 & \cellcolor[HTML]{ec5c3b}{\color[HTML]{f1f1f1} 0.19}  & \cellcolor[HTML]{fb9d59}{\color[HTML]{000000} 0.24}  & \cellcolor[HTML]{f36b42}{\color[HTML]{f1f1f1} 0.20}  & \cellcolor[HTML]{fca55d}{\color[HTML]{000000} 0.24}  & \cellcolor[HTML]{fa9b58}{\color[HTML]{000000} 0.23}  & \cellcolor[HTML]{f88950}{\color[HTML]{f1f1f1} 0.22}  & \cellcolor[HTML]{fed27f}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{fdb163}{\color[HTML]{000000} 0.25}  & \cellcolor[HTML]{f99153}{\color[HTML]{000000} 0.23}  \\
# Reds & 7 & \cellcolor[HTML]{d22b27}{\color[HTML]{f1f1f1} 0.16}  & \cellcolor[HTML]{dc3b2c}{\color[HTML]{f1f1f1} 0.17}  & \cellcolor[HTML]{a50026}{\color[HTML]{f1f1f1} 0.12}  & \cellcolor[HTML]{e65036}{\color[HTML]{f1f1f1} 0.19}  & \cellcolor[HTML]{dc3b2c}{\color[HTML]{f1f1f1} 0.17}  & \cellcolor[HTML]{cc2627}{\color[HTML]{f1f1f1} 0.16}  & \cellcolor[HTML]{f57245}{\color[HTML]{f1f1f1} 0.21}  & \cellcolor[HTML]{f7844e}{\color[HTML]{f1f1f1} 0.22}  & \cellcolor[HTML]{d22b27}{\color[HTML]{f1f1f1} 0.16}  \\
# Rmms & 3 & \cellcolor[HTML]{fed481}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{fff0a6}{\color[HTML]{000000} 0.31}  & \cellcolor[HTML]{fff1a8}{\color[HTML]{000000} 0.31}  & \cellcolor[HTML]{f7fcb4}{\color[HTML]{000000} 0.34}  & \cellcolor[HTML]{fff2aa}{\color[HTML]{000000} 0.31}  & \cellcolor[HTML]{fff6b0}{\color[HTML]{000000} 0.32}  & \cellcolor[HTML]{fafdb8}{\color[HTML]{000000} 0.33}  & \cellcolor[HTML]{fffab6}{\color[HTML]{000000} 0.32}  & \cellcolor[HTML]{e5f49b}{\color[HTML]{000000} 0.36}  \\
# Rmms & 5 & \cellcolor[HTML]{fed683}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{fed07e}{\color[HTML]{000000} 0.27}  & \cellcolor[HTML]{fed884}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{feda86}{\color[HTML]{000000} 0.28}  & \cellcolor[HTML]{fee28f}{\color[HTML]{000000} 0.29}  & \cellcolor[HTML]{fdc171}{\color[HTML]{000000} 0.26}  & \cellcolor[HTML]{fbfdba}{\color[HTML]{000000} 0.33}  & \cellcolor[HTML]{feefa3}{\color[HTML]{000000} 0.31}  & \cellcolor[HTML]{fff2aa}{\color[HTML]{000000} 0.31}  \\
# Rmms & 7 & \cellcolor[HTML]{fba05b}{\color[HTML]{000000} 0.24}  & \cellcolor[HTML]{fdaf62}{\color[HTML]{000000} 0.25}  & \cellcolor[HTML]{fdbd6d}{\color[HTML]{000000} 0.26}  & \cellcolor[HTML]{fa9857}{\color[HTML]{000000} 0.23}  & \cellcolor[HTML]{fdb365}{\color[HTML]{000000} 0.25}  & \cellcolor[HTML]{fa9656}{\color[HTML]{000000} 0.23}  & \cellcolor[HTML]{fdbd6d}{\color[HTML]{000000} 0.26}  & \cellcolor[HTML]{fdad60}{\color[HTML]{000000} 0.24}  & \cellcolor[HTML]{fdbd6d}{\color[HTML]{000000} 0.26}  \\
# Rrv2 & 3 & \cellcolor[HTML]{0e8245}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{108647}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{006837}{\color[HTML]{f1f1f1} 0.53}  & \cellcolor[HTML]{0f8446}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{0d8044}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{18954f}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{15904c}{\color[HTML]{f1f1f1} 0.50}  & \cellcolor[HTML]{42ac5a}{\color[HTML]{f1f1f1} 0.47}  \\
# Rrv2 & 5 & \cellcolor[HTML]{026c39}{\color[HTML]{f1f1f1} 0.53}  & \cellcolor[HTML]{0e8245}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{219c52}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{16914d}{\color[HTML]{f1f1f1} 0.50}  & \cellcolor[HTML]{249d53}{\color[HTML]{f1f1f1} 0.48}  & \cellcolor[HTML]{2da155}{\color[HTML]{f1f1f1} 0.48}  & \cellcolor[HTML]{17934e}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{2da155}{\color[HTML]{f1f1f1} 0.48}  & \cellcolor[HTML]{2aa054}{\color[HTML]{f1f1f1} 0.48}  \\
# Rrv2 & 7 & \cellcolor[HTML]{0c7f43}{\color[HTML]{f1f1f1} 0.51}  & \cellcolor[HTML]{04703b}{\color[HTML]{f1f1f1} 0.53}  & \cellcolor[HTML]{17934e}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{219c52}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{199750}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{1b9950}{\color[HTML]{f1f1f1} 0.49}  & \cellcolor[HTML]{30a356}{\color[HTML]{f1f1f1} 0.48}  & \cellcolor[HTML]{36a657}{\color[HTML]{f1f1f1} 0.48}  & \cellcolor[HTML]{4bb05c}{\color[HTML]{f1f1f1} 0.46}  \\
# \end{tabular}
